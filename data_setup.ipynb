# %% [markdown]
# # Annotate the dataset once and for all
#
# So we can just load it and use it.
#
#
# Stephen Fleming
#
# 2022.12.01

# %%
import anndata
import numpy as np
import pandas as pd
import os
import gc

# %%
DATA_DIR = 'data'

# %% [markdown]
# # Load dataset

# %%
adata = anndata.read_h5ad(os.path.join(DATA_DIR, 'scLevyAll.h5ad'))
adata
# Out:
# AnnData object with n_obs × n_vars = 1276568 × 37701

# %% [markdown]
# # Annotate with metadata

# %%
# metadata
metadata = pd.read_csv(
    os.path.join(DATA_DIR, 'scLevyAll_metadata.txt'),
    sep='\t',
    header=0,
    index_col=False,
)

# rename columns for aesthetic purposes
metadata = metadata.rename(columns={'PREFIX': 'sample', 
                                    'CELL_BARCODE': 'barcode',
                                    'predClass': 'pred_class',
                                    'DONOR': 'donor',
                                    'NUM_GENIC_READS': 'num_genic_reads',
                                    'NUM_TRANSCRIPTS': 'num_transcripts',
                                    'NUM_GENES': 'num_genes',
                                    'bestSample': 'best_sample',
                                    'bestLikelihood': 'best_likelihood'})

# index will be sample_barcode
metadata.index = metadata['sample'].astype(str) + '_' + metadata['barcode'].astype(str)

# limit metadata to cells we actually have in the dataset
metadata = metadata.loc[adata.obs.index]

# add metadata to adata
adata.obs = metadata

# add a few more annotations
def _get_condition(sample):
    s = sample.split('_')
    if len(s) == 2:
        return 'control'
    else:
        return '_'.join(s[1:-1])
    
def _get_celltype(sample):
    return sample.split('_')[0]

adata.obs['cell_type'] = adata.obs['sample'].astype(str).apply(_get_celltype)
adata.obs['condition'] = adata.obs['sample'].astype(str).apply(_get_condition)
adata.obs['perturbation'] = adata.obs['condition'].apply(lambda s: s.split('_')[0])  # no time info

# add in some donor info: diagnosis, age, sex, genetics
donor_df = pd.read_csv(
    os.path.join(DATA_DIR, 'McleanLevy_Dropulation_Cohort.csv'),
    header=0,
    index_col=False,
)
donor_df = donor_df.rename(columns={'Linking Donor ID': 'donor',
                                    'Clinical Diagnosis': 'clinical_diagnosis',
                                    'Age': 'age',
                                    'Sex': 'sex',
                                    'Genetics': 'genetics'})
adata.obs = adata.obs.reset_index().merge(
    right=donor_df[['donor', 'clinical_diagnosis', 'age', 'sex', 'genetics']],
    how='left',
    on='donor',
).set_index('index')

# add in some drug info
drug_df = pd.read_csv(
    os.path.join(DATA_DIR, 'LevyDrug_class.csv'),
    header=0,
    index_col=False,
)
drug_df = drug_df.rename(columns={'Perturbation': 'perturbation',
                                  'Category': 'perturbation_category',
                                  'Vehicle': 'perturbation_vehicle'})
adata.obs = adata.obs.reset_index().merge(
    right=drug_df,
    how='left',
    on='perturbation',
).set_index('index')

# make stuff categorical
for c in ['sample', 'donor', 'best_sample', 'cell_type', 'condition', 
          'sex', 'genetics', 'clinical_diagnosis',
          'perturbation', 'perturbation_category', 'perturbation_vehicle']:
    adata.obs[c] = adata.obs[c].astype('category')

adata
# Out:
# AnnData object with n_obs × n_vars = 1276568 × 37701
#     obs: 'sample', 'barcode', 'pred_class', 'doublet', 'donor', 'num_genic_reads', 'num_transcripts', 'num_genes', 'best_sample', 'best_likelihood', 'pvalue', 'num_retained_transcripts', 'pct_coding', 'pct_utr', 'pct_intergenic', 'pct_genic', 'pct_intronic', 'pct_mt', 'pct_ribosomal', 'frac_contamination', 'cell_type', 'condition', 'perturbation', 'clinical_diagnosis', 'age', 'sex', 'genetics', 'perturbation_category', 'perturbation_vehicle'

# %%
adata.obs.head()
# Out:
#                                                  sample           barcode  \
# index
# Astrocyte_A1CYTO_a_TGCTCCATCTGCGGGT  Astrocyte_A1CYTO_a  TGCTCCATCTGCGGGT
# Astrocyte_A1CYTO_a_ATGCCTCAGTCACTGT  Astrocyte_A1CYTO_a  ATGCCTCAGTCACTGT
# Astrocyte_A1CYTO_a_AGCCAATAGGCCTTGC  Astrocyte_A1CYTO_a  AGCCAATAGGCCTTGC
# Astrocyte_A1CYTO_a_TTCCACGCAGCCCAGT  Astrocyte_A1CYTO_a  TTCCACGCAGCCCAGT
# Astrocyte_A1CYTO_a_GCCAGCACACAAGGTG  Astrocyte_A1CYTO_a  GCCAGCACACAAGGTG
#
#                                      pred_class  doublet       donor  \
# index
# Astrocyte_A1CYTO_a_TGCTCCATCTGCGGGT         NaN      NaN  ML902-5848
# Astrocyte_A1CYTO_a_ATGCCTCAGTCACTGT         NaN      NaN  ML902-5848
# Astrocyte_A1CYTO_a_AGCCAATAGGCCTTGC         NaN      NaN  ML909-1385
# Astrocyte_A1CYTO_a_TTCCACGCAGCCCAGT         NaN      NaN  ML904-8146
# Astrocyte_A1CYTO_a_GCCAGCACACAAGGTG         NaN      NaN  ML902-5848
#
#                                      num_genic_reads  num_transcripts  \
# index
# Astrocyte_A1CYTO_a_TGCTCCATCTGCGGGT          25479.0          20008.0
# Astrocyte_A1CYTO_a_ATGCCTCAGTCACTGT          24976.0          19621.0
# Astrocyte_A1CYTO_a_AGCCAATAGGCCTTGC          24190.0          18722.0
# Astrocyte_A1CYTO_a_TTCCACGCAGCCCAGT          23625.0          18270.0
# Astrocyte_A1CYTO_a_GCCAGCACACAAGGTG          23675.0          18245.0
#
#                                      num_genes best_sample  best_likelihood  \
# index
# Astrocyte_A1CYTO_a_TGCTCCATCTGCGGGT     5922.0  ML902-5848          -197.33
# Astrocyte_A1CYTO_a_ATGCCTCAGTCACTGT     5944.0  ML902-5848          -227.35
# Astrocyte_A1CYTO_a_AGCCAATAGGCCTTGC     5658.0  ML909-1385          -205.34
# Astrocyte_A1CYTO_a_TTCCACGCAGCCCAGT     5312.0  ML904-8146          -172.97
# Astrocyte_A1CYTO_a_GCCAGCACACAAGGTG     5767.0  ML902-5848          -199.52
#
#                                      ...  frac_contamination  cell_type  \
# index                                ...
# Astrocyte_A1CYTO_a_TGCTCCATCTGCGGGT  ...            0.013364  Astrocyte
# Astrocyte_A1CYTO_a_ATGCCTCAGTCACTGT  ...            0.016097  Astrocyte
# Astrocyte_A1CYTO_a_AGCCAATAGGCCTTGC  ...            0.016857  Astrocyte
# Astrocyte_A1CYTO_a_TTCCACGCAGCCCAGT  ...            0.013659  Astrocyte
# Astrocyte_A1CYTO_a_GCCAGCACACAAGGTG  ...            0.016442  Astrocyte
#
#                                      condition  perturbation  \
# index
# Astrocyte_A1CYTO_a_TGCTCCATCTGCGGGT     A1CYTO        A1CYTO
# Astrocyte_A1CYTO_a_ATGCCTCAGTCACTGT     A1CYTO        A1CYTO
# Astrocyte_A1CYTO_a_AGCCAATAGGCCTTGC     A1CYTO        A1CYTO
# Astrocyte_A1CYTO_a_TTCCACGCAGCCCAGT     A1CYTO        A1CYTO
# Astrocyte_A1CYTO_a_GCCAGCACACAAGGTG     A1CYTO        A1CYTO
#
#                                                                     clinical_diagnosis  \
# index
# Astrocyte_A1CYTO_a_TGCTCCATCTGCGGGT                                Bipolar | Psychosis
# Astrocyte_A1CYTO_a_ATGCCTCAGTCACTGT                                Bipolar | Psychosis
# Astrocyte_A1CYTO_a_AGCCAATAGGCCTTGC  Psychosis - Chronic, NOS | Multiple Substance ...
# Astrocyte_A1CYTO_a_TTCCACGCAGCCCAGT                                    Schizoaffective
# Astrocyte_A1CYTO_a_GCCAGCACACAAGGTG                                Bipolar | Psychosis
#
#                                       age     sex  genetics  \
# index
# Astrocyte_A1CYTO_a_TGCTCCATCTGCGGGT  29.0    Male         -
# Astrocyte_A1CYTO_a_ATGCCTCAGTCACTGT  29.0    Male         -
# Astrocyte_A1CYTO_a_AGCCAATAGGCCTTGC  27.0    Male         -
# Astrocyte_A1CYTO_a_TTCCACGCAGCCCAGT  60.0  Female         -
# Astrocyte_A1CYTO_a_GCCAGCACACAAGGTG  29.0    Male         -
#
#                                      perturbation_category  \
# index
# Astrocyte_A1CYTO_a_TGCTCCATCTGCGGGT  Inflammatory response
# Astrocyte_A1CYTO_a_ATGCCTCAGTCACTGT  Inflammatory response
# Astrocyte_A1CYTO_a_AGCCAATAGGCCTTGC  Inflammatory response
# Astrocyte_A1CYTO_a_TTCCACGCAGCCCAGT  Inflammatory response
# Astrocyte_A1CYTO_a_GCCAGCACACAAGGTG  Inflammatory response
#
#                                      perturbation_vehicle
# index
# Astrocyte_A1CYTO_a_TGCTCCATCTGCGGGT                   PBS
# Astrocyte_A1CYTO_a_ATGCCTCAGTCACTGT                   PBS
# Astrocyte_A1CYTO_a_AGCCAATAGGCCTTGC                   PBS
# Astrocyte_A1CYTO_a_TTCCACGCAGCCCAGT                   PBS
# Astrocyte_A1CYTO_a_GCCAGCACACAAGGTG                   PBS
#
# [5 rows x 29 columns]

# %% [markdown]
# # Checks

# %%
adata.obs['cell_type'].value_counts()
# Out:
# Astrocyte    673130
# Neuron       441795
# NPC          103147
# iPSC          58496
# Name: cell_type, dtype: int64

# %%
adata.obs['condition'].value_counts()
# Out:
# control      380816
# DMSO_24hr     96509
# DMSO_72hr     89632
# GLUT          61104
# TNFa          57998
# CLOZ          57955
# HALO          55249
# AZT           50400
# ATOR          47330
# EFA           44772
# SIM           42997
# C1Q           40087
# PBS_24hr      36245
# H2O2          33514
# A1CYTO        32905
# IL1a          31863
# INFy_24hr     23867
# ISRD          20455
# GluN2a        19526
# INFy_7hr      18346
# PBS_7hr       17531
# INFa_7hr      17467
# Name: condition, dtype: int64

# %%
pd.crosstab(adata.obs['condition'], adata.obs['perturbation'])
# Out:
# condition        ATOR    AZT   CLOZ   DMSO    EFA   GLUT  GluN2a  H2O2   HALO  \
# full_condition
# ATOR            13371      0      0      0      0      0       0     0      0
# AZT                 0  16751      0      0      0      0       0     0      0
# CLOZ                0      0  19735      0      0      0       0     0      0
# DMSO_24hr           0      0      0  42256      0      0       0     0      0
# DMSO_72hr           0      0      0  49773      0      0       0     0      0
# EFA                 0      0      0      0  11768      0       0     0      0
# GLUT                0      0      0      0      0  24377       0     0      0
# GluN2a              0      0      0      0      0      0   19526     0      0
# H2O2                0      0      0      0      0      0       0  5346      0
# HALO                0      0      0      0      0      0       0     0  18116
# INFa_7hr            0      0      0      0      0      0       0     0      0
# INFy_24hr           0      0      0      0      0      0       0     0      0
# INFy_7hr            0      0      0      0      0      0       0     0      0
# ISRD                0      0      0      0      0      0       0     0      0
# PBS_24hr            0      0      0      0      0      0       0     0      0
# PBS_7hr             0      0      0      0      0      0       0     0      0
# SIM                 0      0      0      0      0      0       0     0      0
# TNFa                0      0      0      0      0      0       0     0      0
# control             0      0      0      0      0      0       0     0      0
#
# condition        INFa   INFy   ISRD    PBS   SIM   TNFa  control
# full_condition
# ATOR                0      0      0      0     0      0        0
# AZT                 0      0      0      0     0      0        0
# CLOZ                0      0      0      0     0      0        0
# DMSO_24hr           0      0      0      0     0      0        0
# DMSO_72hr           0      0      0      0     0      0        0
# EFA                 0      0      0      0     0      0        0
# GLUT                0      0      0      0     0      0        0
# GluN2a              0      0      0      0     0      0        0
# H2O2                0      0      0      0     0      0        0
# HALO                0      0      0      0     0      0        0
# INFa_7hr        17467      0      0      0     0      0        0
# INFy_24hr           0  23867      0      0     0      0        0
# INFy_7hr            0  18346      0      0     0      0        0
# ISRD                0      0  20455      0     0      0        0
# PBS_24hr            0      0      0  10862     0      0        0
# PBS_7hr             0      0      0  17531     0      0        0
# SIM                 0      0      0      0  6909      0        0
# TNFa                0      0      0      0     0  19269        0
# control             0      0      0      0     0      0    86070

# %%
pd.crosstab(adata.obs['perturbation'], adata.obs['cell_type'])
# Out:
# cell_type     Astrocyte     NPC  Neuron   iPSC
# perturbation
# A1CYTO            32905       0       0      0
# ATOR              33959       0   13371      0
# AZT               33649       0   16751      0
# C1Q               40087       0       0      0
# CLOZ              38220       0   19735      0
# ML898-3533       61    182      0   209   458   243    326     66    216
# ML898-4425        3     27      0     0    51    50     21      8      0
# ML898-5426       48    141      0   157   348   166    224     44    161
# ML902-5848    17377  21195  19265     0     0     0  14783  17767  22778
# ML902-9860     4796   7144   5746   135   294   150   4644   6977   8140
# ML904-1257       88    422      0   371   786   355    670    236    485
# ML904-7021      236    392    279   120   315   139    427    424    433
# ML904-8146     1427   2633   1075  1106  2637  1358   2796   2542   2258
# ML907-2836        0      0      0     0     0     0      0      0      0
# ML907-6335      104    329      0   280   723   325    538    125    381
# ML909-1385     1671   3909    807  2947  6858  3276   5227   2608   4098
# ML909-4644      221    735      0   702  1609   752   1071    330    635
# ML909-4808        9      0      0    19    29     0     22     15     23
# ML909-6344      446    733    308   402  1040   450    976    430    840
# ML910-6105      385   1032    239   711  1761   983   1186    567    760
# ML910-8360      139    320    106   156   384   163    362    371    285
# ML910-8726       66    412      0   244   601   320    581    223    290
# ML911-1181        0      0      0     0     0     0     19      9      0
# ML911-2118      161    387    118   187   558   204    479    325    353
# ML911-9779      712   1925    272  1468  3398  1893   2709   1268   2218
# ML930-3829        0      0      0     0     0     0      0      0      0
# ML930-5252      114    463      0   460  1078   504    761    127    527
# ML930-6062      203    547     99   417   965   457    797    271    605
#
# perturbation  control
# donor
# CW20183         10113
# ML611-2911       5215
# ML611-3363       4487
# ML611-5459       5893
# ML730-5535       5245
# ML730-7078      15184
# ML730-8735       4632
# ML787-6234      15274
# ML787-7283       5875
# ML830-2683       4421
# ML830-5578       4860
# ML830-8410      10732
# ML832-1814       5412
# ML832-2002       7538
# ML832-3550       4599
# ML832-6778       5283
# ML844-1313       5335
# ML844-6618       5228
# ML844-7455         31
# ML898-3533       5807
# ML898-4425        862
# ML898-5426       4017
# ML902-5848      75373
# ML902-9860      30994
# ML904-1257       6921
# ML904-7021       5651
# ML904-8146      17112
# ML907-2836       2644
# ML907-6335       5477
# ML909-1385      22103
# ML909-4644       8075
# ML909-4808       4440
# ML909-6344       7448
# ML910-6105       6464
# ML910-8360       4483
# ML910-8726       6525
# ML911-1181       1867
# ML911-2118       6260
# ML911-9779      15482
# ML930-3829       3555
# ML930-5252       7780
# ML930-6062       6119

# %% [markdown]
# # Write annotated dataset

# %%
adata.write(os.path.join(DATA_DIR, 'sc_levy_annotated.h5ad'))

# %%
# !ls -lh {DATA_DIR}
# Out:
# total 41G
# -rw-r--r-- 1 sfleming sfleming  596 Dec  1 17:44 LevyDrug_class.csv
# -rw-r--r-- 1 sfleming sfleming 7.1K Dec  1 17:44 McleanLevy_Dropulation_Cohort.csv
# -rw-rw-r-- 1 sfleming sfleming 6.1G Dec  1 17:46 scLevyAll.h5ad
# -rw-rw-r-- 1 sfleming sfleming 502M Dec  1 17:47 scLevyAll_metadata.txt
# -rw-rw-r-- 1 sfleming sfleming  35G Dec  1 20:17 sc_levy_annotated.h5ad
